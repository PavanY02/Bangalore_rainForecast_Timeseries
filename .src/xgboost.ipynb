# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in /usr/local/lib/python3.10/dist-packages (2.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from xgboost) (1.26.4)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.10/dist-packages (from xgboost) (2.23.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from xgboost) (1.13.1)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from xgboost import XGBClassifier
from sklearn.preprocessing import StandardScaler,MinMaxScaler

# %%
# Load the data
file_path = '/content/BangloreDATA.csv'
data = pd.read_csv(file_path)


print(data.head())
# Out:
#    YEAR  MO  DY  WS2M    T2M     TS  T2M_RANGE  T2M_MAX  T2M_MIN  PRECTOTCORR  \
# 0  1981   1   1  2.85  21.00  22.26      14.48    29.09    14.62         0.00
# 1  1981   1   2  1.91  21.53  23.05      13.55    29.12    15.58         0.42
# 2  1981   1   3  2.41  21.14  22.53      13.03    29.07    16.04         0.86
# 3  1981   1   4  2.23  20.84  22.24      14.09    29.33    15.24         0.00
# 4  1981   1   5  1.73  20.61  22.21      16.45    30.23    13.77         0.00
#
#     RH2M   QV2M     PS  WS10M  WS50M   WD50M   WD10M  RainToday  RainTomorrow
# 0  68.69  10.80  91.90   4.05   5.69   83.75   83.81          0             1
# 1  69.00  11.17  91.87   2.77   4.12   86.19   87.00          1             1
# 2  68.69  10.86  91.88   3.48   5.16   75.94   76.75          1             0
# 3  64.00   9.70  91.90   3.26   4.94   85.88   87.00          0             0
# 4  62.44   9.09  91.94   2.59   4.11  102.56  104.31          0             0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15706 entries, 0 to 15705
# Data columns (total 19 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   YEAR          15706 non-null  int64
#  1   MO            15706 non-null  int64
#  2   DY            15706 non-null  int64
#  3   WS2M          15706 non-null  float64
#  4   T2M           15706 non-null  float64
#  5   TS            15706 non-null  float64
#  6   T2M_RANGE     15706 non-null  float64
#  7   T2M_MAX       15706 non-null  float64
#  8   T2M_MIN       15706 non-null  float64
#  9   PRECTOTCORR   15706 non-null  float64
#  10  RH2M          15706 non-null  float64
#  11  QV2M          15706 non-null  float64
#  12  PS            15706 non-null  float64
#  13  WS10M         15706 non-null  float64
#  14  WS50M         15706 non-null  float64
#  15  WD50M         15706 non-null  float64
#  16  WD10M         15706 non-null  float64
#  17  RainToday     15706 non-null  int64
#  18  RainTomorrow  15706 non-null  int64
# dtypes: float64(14), int64(5)
# memory usage: 2.3 MB

# %%
sns.countplot(x='RainTomorrow', data=data)
plt.title('Distribution of RainTomorrow')
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(data.corr(), annot=True, fmt=".2f", cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %%
# Correlation with RainTomorrow
correlation_matrix = data.corr()
target_correlation = correlation_matrix['RainTomorrow'].sort_values(ascending=False)

# Print the top 5 most correlated features
print("Top correlated features with RainTomorrow:")
print(target_correlation.head(6))
# Out:
# Top correlated features with RainTomorrow:
# RainTomorrow    1.000000
# RainToday       0.727364
# QV2M            0.698980
# RH2M            0.538817
# WD50M           0.454320
# WD10M           0.453894
# Name: RainTomorrow, dtype: float64

# %%
features = ['WS2M', 'T2M', 'TS', 'T2M_RANGE', 'T2M_MAX', 'T2M_MIN',
            'PRECTOTCORR', 'RH2M', 'QV2M', 'PS', 'WS10M', 'WS50M',
            'WD50M', 'WD10M', 'RainToday']
target = 'RainTomorrow'

X = data[features]
y = data[target]

# %%
data.rename(columns={'Yr': 'YEAR', 'MO': 'Month', 'DY': 'Day',"PRECTOTCORR":"Precipitation"}, inplace=True)

# %%
data['Date'] = pd.to_datetime(data[['YEAR', 'Month', 'Day']])
data['Date'] = pd.to_datetime(data['Date'])
data.set_index('Date', inplace=True)

# %%
features_to_lag = ['RainToday', 'QV2M', 'RH2M', 'WD50M', 'WD10M']

# %%
num_lags = 7

# %%
for feature in features_to_lag:
    for lag in range(1, num_lags + 1):
        data[f'{feature}_lag{lag}'] = data[feature].shift(lag)


data = data.dropna().reset_index(drop=True)

# %%
X = data.drop(columns=['RainTomorrow'])
y = data['RainTomorrow']

print(f"X shape: {X.shape}, y shape: {y.shape}")

train_size = int(0.8 * len(X))

X_train_full, X_test = X.iloc[:train_size], X.iloc[train_size:]
y_train_full, y_test = y.iloc[:train_size], y.iloc[train_size:]
# Out:
# X shape: (15699, 53), y shape: (15699,)

# %%
print(f"Train shape: {X_train_full.shape}, Test shape: {X_test.shape}")
print(f"Train shape: {y_train_full.shape}, Test shape: {y_test.shape}")
# Out:
# Train shape: (12559, 53), Test shape: (3140, 53)
# Train shape: (12559,), Test shape: (3140,)

# %%
train_size = int(0.8 * len(X_train_full))

X_train, X_validation = X_train_full.iloc[:train_size], X_train_full.iloc[train_size:]
y_train, y_validation = y_train_full.iloc[:train_size], y_train_full.iloc[train_size:]

# %%
print(f"Train shape: {X_train.shape}, Validation shape: {X_validation.shape}")
print(f"Train shape: {y_train.shape}, Validation shape: {y_validation.shape}")
# Out:
# Train shape: (10047, 53), Validation shape: (2512, 53)
# Train shape: (10047,), Validation shape: (2512,)

# %%
scaler = MinMaxScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_validation_scaled = scaler.transform(X_validation)
X_test_scaled = scaler.transform(X_test)

# %%
from xgboost import XGBClassifier

xgb_model = XGBClassifier(
    n_estimators=200,
    max_depth=8,
    learning_rate=0.1,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=42
)


xgb_model.fit(
    X_train_scaled,
    y_train,
    eval_set=[(X_validation_scaled, y_validation)], 
    verbose=True  
)
# Out:
# [0]	validation_0-logloss:0.61881
# [1]	validation_0-logloss:0.57039
# [2]	validation_0-logloss:0.53144
# [3]	validation_0-logloss:0.49889
# [4]	validation_0-logloss:0.47111
# [5]	validation_0-logloss:0.44640
# [6]	validation_0-logloss:0.42704
# [7]	validation_0-logloss:0.40922
# [8]	validation_0-logloss:0.39397
# [9]	validation_0-logloss:0.38172
# [10]	validation_0-logloss:0.37055
# [11]	validation_0-logloss:0.36086
# [12]	validation_0-logloss:0.35410
# [13]	validation_0-logloss:0.34718
# [14]	validation_0-logloss:0.34157
# [15]	validation_0-logloss:0.33600
# [16]	validation_0-logloss:0.33171
# [17]	validation_0-logloss:0.32886
# [18]	validation_0-logloss:0.32514
# [19]	validation_0-logloss:0.32312
# [20]	validation_0-logloss:0.32027
# [21]	validation_0-logloss:0.31909
# [22]	validation_0-logloss:0.31719
# [23]	validation_0-logloss:0.31527
# [24]	validation_0-logloss:0.31351
# [25]	validation_0-logloss:0.31252
# [26]	validation_0-logloss:0.31045
# [27]	validation_0-logloss:0.31035
# [28]	validation_0-logloss:0.30915
# [29]	validation_0-logloss:0.30824
# [30]	validation_0-logloss:0.30681
# [31]	validation_0-logloss:0.30587
# [32]	validation_0-logloss:0.30508
# [33]	validation_0-logloss:0.30442
# [34]	validation_0-logloss:0.30387
# [35]	validation_0-logloss:0.30319
# [36]	validation_0-logloss:0.30294
# [37]	validation_0-logloss:0.30297
# [38]	validation_0-logloss:0.30262
# [39]	validation_0-logloss:0.30312
# [40]	validation_0-logloss:0.30329
# [41]	validation_0-logloss:0.30257
# [42]	validation_0-logloss:0.30220
# [43]	validation_0-logloss:0.30243
# [44]	validation_0-logloss:0.30289
# [45]	validation_0-logloss:0.30305
# [46]	validation_0-logloss:0.30375
# [47]	validation_0-logloss:0.30425
# [48]	validation_0-logloss:0.30405
# [49]	validation_0-logloss:0.30456
# [50]	validation_0-logloss:0.30492
# [51]	validation_0-logloss:0.30480
# [52]	validation_0-logloss:0.30445
# [53]	validation_0-logloss:0.30417
# [54]	validation_0-logloss:0.30441
# [55]	validation_0-logloss:0.30463
# [56]	validation_0-logloss:0.30538
# [57]	validation_0-logloss:0.30530
# [58]	validation_0-logloss:0.30578
# [59]	validation_0-logloss:0.30625
# [60]	validation_0-logloss:0.30716
# [61]	validation_0-logloss:0.30771
# [62]	validation_0-logloss:0.30877
# [63]	validation_0-logloss:0.30886
# [64]	validation_0-logloss:0.30919
# [65]	validation_0-logloss:0.30925
# [66]	validation_0-logloss:0.31014
# [67]	validation_0-logloss:0.31031
# [68]	validation_0-logloss:0.31070
# [69]	validation_0-logloss:0.31106
# [70]	validation_0-logloss:0.31090
# [71]	validation_0-logloss:0.31121
# [72]	validation_0-logloss:0.31113
# [73]	validation_0-logloss:0.31186
# [74]	validation_0-logloss:0.31220
# [75]	validation_0-logloss:0.31300
# [76]	validation_0-logloss:0.31346
# [77]	validation_0-logloss:0.31363
# [78]	validation_0-logloss:0.31366
# [79]	validation_0-logloss:0.31345
# [80]	validation_0-logloss:0.31415
# [81]	validation_0-logloss:0.31424
# [82]	validation_0-logloss:0.31468
# [83]	validation_0-logloss:0.31484
# [84]	validation_0-logloss:0.31492
# [85]	validation_0-logloss:0.31555
# [86]	validation_0-logloss:0.31588
# [87]	validation_0-logloss:0.31652
# [88]	validation_0-logloss:0.31710
# [89]	validation_0-logloss:0.31727
# [90]	validation_0-logloss:0.31741
# [91]	validation_0-logloss:0.31761
# [92]	validation_0-logloss:0.31808
# [93]	validation_0-logloss:0.31871
# [94]	validation_0-logloss:0.31808
# [95]	validation_0-logloss:0.31807
# [96]	validation_0-logloss:0.31824
# [97]	validation_0-logloss:0.31794
# [98]	validation_0-logloss:0.31791
# [99]	validation_0-logloss:0.31827
# [100]	validation_0-logloss:0.31818
# [101]	validation_0-logloss:0.31836
# [102]	validation_0-logloss:0.31808
# [103]	validation_0-logloss:0.31828
# [104]	validation_0-logloss:0.31866
# [105]	validation_0-logloss:0.31904
# [106]	validation_0-logloss:0.31926
# [107]	validation_0-logloss:0.31958
# [108]	validation_0-logloss:0.31965
# [109]	validation_0-logloss:0.31979
# [110]	validation_0-logloss:0.31988
# [111]	validation_0-logloss:0.32041
# [112]	validation_0-logloss:0.32085
# [113]	validation_0-logloss:0.32074
# [114]	validation_0-logloss:0.32072
# [115]	validation_0-logloss:0.32097
# [116]	validation_0-logloss:0.32172
# [117]	validation_0-logloss:0.32182
# [118]	validation_0-logloss:0.32216
# [119]	validation_0-logloss:0.32242
# [120]	validation_0-logloss:0.32285
# [121]	validation_0-logloss:0.32300
# [122]	validation_0-logloss:0.32291
# [123]	validation_0-logloss:0.32299
# [124]	validation_0-logloss:0.32318
# [125]	validation_0-logloss:0.32324
# [126]	validation_0-logloss:0.32411
# [127]	validation_0-logloss:0.32403
# [128]	validation_0-logloss:0.32417
# [129]	validation_0-logloss:0.32405
# [130]	validation_0-logloss:0.32396
# [131]	validation_0-logloss:0.32455
# [132]	validation_0-logloss:0.32464
# [133]	validation_0-logloss:0.32436
# [134]	validation_0-logloss:0.32428
# [135]	validation_0-logloss:0.32501
# [136]	validation_0-logloss:0.32555
# [137]	validation_0-logloss:0.32581
# [138]	validation_0-logloss:0.32643
# [139]	validation_0-logloss:0.32686
# [140]	validation_0-logloss:0.32689
# [141]	validation_0-logloss:0.32738
# [142]	validation_0-logloss:0.32760
# [143]	validation_0-logloss:0.32789
# [144]	validation_0-logloss:0.32811
# [145]	validation_0-logloss:0.32783
# [146]	validation_0-logloss:0.32802
# [147]	validation_0-logloss:0.32827
# [148]	validation_0-logloss:0.32871
# [149]	validation_0-logloss:0.32822
# [150]	validation_0-logloss:0.32813
# [151]	validation_0-logloss:0.32849
# [152]	validation_0-logloss:0.32895
# [153]	validation_0-logloss:0.32889
# [154]	validation_0-logloss:0.32921
# [155]	validation_0-logloss:0.32919
# [156]	validation_0-logloss:0.32919
# [157]	validation_0-logloss:0.32939
# [158]	validation_0-logloss:0.32935
# [159]	validation_0-logloss:0.32932
# [160]	validation_0-logloss:0.32948
# [161]	validation_0-logloss:0.32972
# [162]	validation_0-logloss:0.33022
# [163]	validation_0-logloss:0.33047
# [164]	validation_0-logloss:0.33065
# [165]	validation_0-logloss:0.33040
# [166]	validation_0-logloss:0.33069
# [167]	validation_0-logloss:0.33098
# [168]	validation_0-logloss:0.33131
# [169]	validation_0-logloss:0.33161
# [170]	validation_0-logloss:0.33176
# [171]	validation_0-logloss:0.33242
# [172]	validation_0-logloss:0.33278
# [173]	validation_0-logloss:0.33298
# [174]	validation_0-logloss:0.33375
# [175]	validation_0-logloss:0.33407
# [176]	validation_0-logloss:0.33488
# [177]	validation_0-logloss:0.33539
# [178]	validation_0-logloss:0.33598
# [179]	validation_0-logloss:0.33592
# [180]	validation_0-logloss:0.33603
# [181]	validation_0-logloss:0.33667
# [182]	validation_0-logloss:0.33662
# [183]	validation_0-logloss:0.33708
# [184]	validation_0-logloss:0.33720
# [185]	validation_0-logloss:0.33820
# [186]	validation_0-logloss:0.33845
# [187]	validation_0-logloss:0.33871
# [188]	validation_0-logloss:0.33937
# [189]	validation_0-logloss:0.33936
# [190]	validation_0-logloss:0.33960
# [191]	validation_0-logloss:0.33982
# [192]	validation_0-logloss:0.33959
# [193]	validation_0-logloss:0.34055
# [194]	validation_0-logloss:0.34069
# [195]	validation_0-logloss:0.34079
# [196]	validation_0-logloss:0.34094
# [197]	validation_0-logloss:0.34126
# [198]	validation_0-logloss:0.34132
# [199]	validation_0-logloss:0.34165
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=8, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, random_state=42, ...)

# %%
y_test_pred = xgb_model.predict(X_test_scaled)
test_accuracy = accuracy_score(y_test, y_test_pred)
print(test_accuracy)
# Out:
# 0.8726114649681529

# %%
conf_matrix = confusion_matrix(y_test, y_test_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['No Rain', 'Rain'], yticklabels=['No Rain', 'Rain'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
print("Classification Report:\n", classification_report(y_test, y_test_pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.87      0.80      0.83      1245
#            1       0.87      0.92      0.90      1895
#
#     accuracy                           0.87      3140
#    macro avg       0.87      0.86      0.86      3140
# weighted avg       0.87      0.87      0.87      3140

# %%
feature_importances = xgb_model.feature_importances_
sorted_idx = feature_importances.argsort()
plt.figure(figsize=(10, 8))
plt.barh(range(len(sorted_idx)), feature_importances[sorted_idx])
plt.yticks(range(len(sorted_idx)), X.columns[sorted_idx])
plt.title('Feature Importances')
plt.show()
print(f"Test Accuracy: {test_accuracy:.2f}")
# Out:
# Test Accuracy: 0.87

# %%
import pickle

# Save the trained model to a file
with open('xgb_model.pkl', 'wb') as file:
    pickle.dump(xgb_model, file)

print("Model saved as 'xgb_model.pkl'")
# Out:
# Model saved as 'xgb_model.pkl'
